# %%
# %env GOOGLE_APPLICATION_CREDENTIALS=/Users/roger/Drive_Artefact/TMALL/Code/Data Sandbox-3580c14f7592.json
# Out:
# env: GOOGLE_APPLICATION_CREDENTIALS=/Users/roger/Drive_Artefact/TMALL/Code/Data Sandbox-3580c14f7592.json

# %%
import re
import pprint
import io
import os
# Imports the Google Cloud client library
from google.cloud import vision
from google.cloud.vision import types

# Instantiates a client
client = vision.ImageAnnotatorClient()

path = 'data/'

files = []
# r=root, d=directories, f = files
for r, d, f in os.walk(path):
    for file in f:
        if '.jpg' in file:
            files.append(os.path.join(r, file))
path = []
for f in files:
    path.append(f.split('/')[0]+ '/' + f.split('/')[1] + '/')

file_names= []
for f in files:
    file_names.append(f.split('/')[2].split('.')[0])

# %%
path
# Out:
# ["data/L'OREAL 欧莱雅 恒放溢彩雾感唇釉/",
#  "data/L'OREAL 欧莱雅 清润红石榴鲜粹面膜/",
#  'data/error_20190320_191821/',
#  'data/L＇oreal欧莱雅 茶树植萃去屑滋养洗发露/',
#  'data/error_20190320_192255/',
#  'data/error_20190320_191827/',
#  "data/L'OREAL 欧莱雅 清润葡萄籽鲜粹精华液/",
#  'data/L＇oreal欧莱雅 奇焕光感粉嫩透亮修颜霜/',
#  'data/error_20190320_191811/',
#  "data/L'OREAL 欧莱雅 强塑定型三孔喷雾/",
#  "data/L'OREAL 欧莱雅 奇焕润发精油(针对极度干枯发质)/",
#  'data/L＇oreal欧莱雅 男士火山岩清痘冰感水凝露/',
#  'data/error_20190320_192147/',
#  'data/error_20190320_191738/',
#  "data/L'OREAL 欧莱雅 青春密码酵素精华肌底液/",
#  "data/L'OREAL 欧莱雅 清润葡萄籽精华膜力水/",
#  "data/L'OREAL 欧莱雅 男士锐能抗皱紧致多效霜/",
#  'data/error_20190320_192115/',
#  'data/L＇oreal欧莱雅 男士水能保湿滋润乳/',
#  "data/L'OREAL 欧莱雅 精油润养润发乳/",
#  "data/L'OREAL 欧莱雅 纷泽溢彩釉光唇膏/",
#  "data/L'OREAL欧莱雅 透明质酸水润去屑洗发露(倍爽)/",
#  'data/error_20190320_192141/',
#  'data/L＇oreal欧莱雅 男士水能润泽双效洁面膏/',
#  'data/L＇oreal欧莱雅 男士水能保湿强润霜/',
#  'data/error_20190320_192249/',
#  "data/L'OREAL 欧莱雅 恒放溢彩持色哑光遮瑕轻垫霜/",
#  'data/error_20190320_192026/',
#  'data/L＇oreal欧莱雅 男士水能润泽净爽洁面啫喱/',
#  "data/L'OREAL 欧莱雅 精油润养洗发露/",
#  'data/error_20190320_191651/',
#  'data/error_20190320_192016/',
#  'data/error_20190320_191624/',
#  'data/L＇oreal欧莱雅 三合一卸妆洁颜水 深澈型/',
#  'data/error_20190320_192202/',
#  'data/error_20190320_192054/',
#  "data/L'OREAL 欧莱雅 奇焕润发精油 适合各种发质/",
#  'data/error_20190320_191622/',
#  "data/L'OREAL欧莱雅 男士去屑洗发露(炭爽去油)/",
#  'data/error_20190320_192009/',
#  "data/L'OREAL 欧莱雅 男士火山岩控油清痘洁面膏/",
#  'data/L＇oreal欧莱雅 男士水能保湿酷爽水凝露/',
#  "data/L'OREAL 欧莱雅 复颜抗皱紧致滋润日霜/",
#  "data/L'OREAL 欧莱雅 复颜玻尿酸水光充盈全脸淡纹眼霜/",
#  'data/巴黎欧莱雅 复颜紧致三件套超值组合/',
#  "data/L'OREAL 欧莱雅 恒放溢彩持色哑光粉底液/",
#  'data/L＇oreal欧莱雅 男士控油炭爽抗黑头洁面膏/',
#  "data/L'OREAL 欧莱雅 轻爽塑型啫喱/",
#  "data/L'OREAL 欧莱雅 三合一卸妆洁颜水清爽型/",
#  'data/error_20190320_191744/',
#  'data/error_20190320_192132/',
#  'data/error_20190320_192104/',
#  'data/L＇oreal欧莱雅 多重防护隔离露(特护升级)SPF30+PA+++/',
#  'data/error_20190320_191710/',
#  "data/L'OREAL 欧莱雅 茶树植萃去屑净油洗发露/",
#  'data/L＇oreal欧莱雅 透明质酸水润洗发露/',
#  "data/L'OREAL 欧莱雅 清润葡萄籽水嫩洁面乳/",
#  "data/L'OREAL 欧莱雅 奇焕润发精油/",
#  'data/L＇oreal欧莱雅 清润葡萄籽水嫩膜力眼霜/',
#  'data/L＇oreal欧莱雅 复颜洁面乳/']

# %%
for counter, f in enumerate(files):
    
    # Loads the image into memory
    with io.open(f, 'rb') as image_file:
        content = image_file.read()

    image = types.Image(content=content)

    # Performs label detection on the image file
    response = client.text_detection(image=image)
    texts = response.text_annotations
    
    doc_txt = open(path[counter] + "text.txt","w")
    doc_txt.write(texts[0].description)
    doc_txt.close()
    
    doc_desc = open(path[counter] + "desc.txt","w")

    for text in texts[1:]:
        vertices = (['({},{})'.format(vertex.x, vertex.y)
                    for vertex in text.bounding_poly.vertices])
        doc_desc.write('\n"{}"'.format(text.description))
        doc_desc.write('bounds: {}'.format(','.join(vertices)))
    doc_desc.close()
    
    response = client.label_detection(image=image)
    labels = response.label_annotations
    doc_label = open(path[counter] + "label.txt","w")
    for label in labels:
        doc_label.write(label.description + ': '+ "{:.2f}".format(label.score) + '\n')
    doc_label.close()
# Out:
# Red : 0.95
#
# Cosmetics : 0.94
#
# Lip : 0.94
#
# Lipstick : 0.92
#
# Product : 0.91
#
# Beauty : 0.89
#
# Lip gloss : 0.82
#
# Pink : 0.81
#
# Lip care : 0.76
#
# Material property : 0.74
#
# Pink : 0.88
#
# Font : 0.78
#
# Material property : 0.70
#
# Magenta : 0.70
#
# Advertising : 0.53
#
# Product : 0.95
#
# Material property : 0.72
#
# Personal care : 0.60
#
# Electric blue : 0.58
#
# Skin care : 0.56
#
# Hair care : 0.55
#
# Hair coloring : 0.51
#
# Product : 0.88
#
# Liquid : 0.57
#
# Product : 0.97
#
# Pink : 0.92
#
# Skin care : 0.81
#
# Liquid : 0.74
#
# Cosmetics : 0.73
#
# Material property : 0.72
#
# Fluid : 0.60
#
# Tints and shades : 0.56
#
# Gloss : 0.55
#
# Moisture : 0.55
#
# Product : 0.96
#
# Water : 0.81
#
# Spray : 0.79
#
# Bottle : 0.76
#
# Liquid : 0.71
#
# Material property : 0.70
#
# Plastic bottle : 0.65
#
# Cosmetics : 0.60
#
# Fluid : 0.53
#
# Personal care : 0.53
#
# Product : 0.96
#
# Pink : 0.90
#
# Beauty : 0.89
#
# Water : 0.81
#
# Skin care : 0.78
#
# Cosmetics : 0.75
#
# Material property : 0.72
#
# Liquid : 0.65
#
# Fluid : 0.63
#
# Lip care : 0.59
#
# Skin care : 0.90
#
# Product : 0.88
#
# Cosmetics : 0.83
#
# Lip care : 0.78
#
# Cream : 0.77
#
# Font : 0.75
#
# Material property : 0.73
#
# Brand : 0.58
#
# Product : 0.95
#
# Plastic bottle : 0.81
#
# Skin care : 0.74
#
# Spray : 0.72
#
# Material property : 0.71
#
# Bottle : 0.71
#
# Fluid : 0.69
#
# Cosmetics : 0.69
#
# Liquid : 0.67
#
# Tints and shades : 0.52
#
# Product : 0.93
#
# Material property : 0.70
#
# Product : 0.88
#
# Bottle : 0.66
#
# Spray : 0.63
#
# Fluid : 0.51
#
# Product : 0.96
#
# Beauty : 0.88
#
# Personal care : 0.71
#
# Material property : 0.70
#
# Skin care : 0.61
#
# Hair coloring : 0.55
#
# Hair care : 0.52
#
# Lipstick : 0.97
#
# Red : 0.96
#
# Lip : 0.94
#
# Cosmetics : 0.94
#
# Lip care : 0.91
#
# Pink : 0.81
#
# Material property : 0.72
#
# Mouth : 0.68
#
# Tints and shades : 0.60
#
# Lip gloss : 0.55
#
# Product : 0.88
#
# Skin care : 0.55
#
# Product : 0.97
#
# Beauty : 0.86
#
# Water : 0.81
#
# Font : 0.75
#
# Material property : 0.72
#
# Skin care : 0.66
#
# Personal care : 0.58
#
# Hair care : 0.58
#
# Spray : 0.53
#
# Moisture : 0.52
#
# Product : 0.95
#
# Pink : 0.81
#
# Perfume : 0.71
#
# Material property : 0.70
#
# Liquid : 0.64
#
# Fluid : 0.61
#
# Product : 0.95
#
# Hair coloring : 0.83
#
# Skin care : 0.79
#
# Material property : 0.72
#
# Cream : 0.71
#
# Personal care : 0.61
#
# Hair care : 0.55
#
# Product : 0.96
#
# Beauty : 0.87
#
# Skin care : 0.86
#
# Cream : 0.76
#
# Hair coloring : 0.76
#
# Material property : 0.72
#
# Lotion : 0.63
#
# Advertising : 0.61
#
# Hair care : 0.58
#
# Brand : 0.57
#
# Product : 0.93
#
# Material property : 0.71
#
# Product : 0.91
#
# Material property : 0.70
#
# Lip : 0.97
#
# Lipstick : 0.97
#
# Red : 0.95
#
# Cosmetics : 0.93
#
# Pink : 0.93
#
# Lip care : 0.92
#
# Lip gloss : 0.91
#
# Beauty : 0.87
#
# Tints and shades : 0.75
#
# Material property : 0.74
#
# Product : 0.91
#
# Personal care : 0.61
#
# Fluid : 0.53
#
# Material property : 0.72
#
# Hair coloring : 0.60
#
# Cosmetics : 0.52
#
# Liquid : 0.51
#
# Product : 0.88
#
# Skin care : 0.78
#
# Material property : 0.71
#
# Font : 0.69
#
# Hair coloring : 0.64
#
# Personal care : 0.54
#
# Product : 0.91
#
# Font : 0.75
#
# Material property : 0.70
#
# Personal care : 0.53
#
# Hair care : 0.52
#
# Product : 0.91
#
# Material property : 0.72
#
# Skin care : 0.69
#
# Cosmetics : 0.67
#
# Hair coloring : 0.62
#
# Cream : 0.62
#
# Font : 0.82
#
# Fashion accessory : 0.55
#
# Product : 0.96
#
# Cosmetics : 0.88
#
# Liquid : 0.75
#
# Material property : 0.73
#
# Gloss : 0.61
#
# Hair coloring : 0.60
#
# Eyelash : 0.59
#
# Product : 0.95
#
# Skin care : 0.85
#
# Cream : 0.75
#
# Material property : 0.71
#
# Font : 0.69
#
# Brand : 0.60
#
# Acrylic paint : 0.57
#
# Product : 0.91
#
# Material property : 0.71
#
# Personal care : 0.62
#
# Skin care : 0.61
#
# Hair coloring : 0.58
#
# Spray : 0.56
#
# Hair care : 0.50
#
# Product : 0.94
#
# Font : 0.85
#
# Material property : 0.72
#
# Hair coloring : 0.51
#
# Product : 0.96
#
# Water : 0.81
#
# Spray : 0.79
#
# Bottle : 0.76
#
# Liquid : 0.71
#
# Material property : 0.70
#
# Plastic bottle : 0.65
#
# Cosmetics : 0.60
#
# Fluid : 0.53
#
# Personal care : 0.53
#
# Product : 0.97
#
# Pink : 0.92
#
# Skin care : 0.81
#
# Liquid : 0.74
#
# Cosmetics : 0.73
#
# Material property : 0.72
#
# Fluid : 0.60
#
# Tints and shades : 0.56
#
# Gloss : 0.55
#
# Moisture : 0.55
#
# Product : 0.96
#
# Skin care : 0.78
#
# Material property : 0.70
#
# Product : 0.88
#
# Material property : 0.72
#
# Cream : 0.69
#
# Font : 0.69
#
# Skin care : 0.68
#
# Hair coloring : 0.60
#
# Brand : 0.52
#
# Product : 0.95
#
# Red : 0.94
#
# Skin : 0.92
#
# Beauty : 0.90
#
# Skin care : 0.86
#
# Hair coloring : 0.83
#
# Lip : 0.83
#
# Material property : 0.72
#
# Cosmetics : 0.63
#
# Gloss : 0.51
#
# Product : 0.91
#
# Hair coloring : 0.77
#
# Personal care : 0.69
#
# Bottle : 0.58
#
# Skin care : 0.58
#
# Hair care : 0.55
#
# Spray : 0.53
#
# Product : 0.91
#
# Material property : 0.72
#
# Skin care : 0.69
#
# Cosmetics : 0.67
#
# Hair coloring : 0.62
#
# Cream : 0.62
#
# Product : 0.93
#
# Material property : 0.70
#
# Liquid : 0.62
#
# Personal care : 0.53
#
# Hair coloring : 0.51
#
# Product : 0.95
#
# Material property : 0.72
#
# Personal care : 0.60
#
# Electric blue : 0.58
#
# Skin care : 0.56
#
# Hair care : 0.55
#
# Hair coloring : 0.51
#
# Product : 0.95
#
# Hair coloring : 0.79
#
# Skin care : 0.77
#
# Cream : 0.72
#
# Material property : 0.71
#
# Brand : 0.60
#
# Advertising : 0.58
#
# Personal care : 0.54
#
# Product : 0.95
#
# Material property : 0.72
#
# Personal care : 0.68
#
# Hair coloring : 0.62
#
# Hair care : 0.60
#
# Skin care : 0.60
#
# Cosmetics : 0.58
#
# Product : 0.95
#
# Red : 0.95
#
# Skin care : 0.91
#
# Beauty : 0.86
#
# Cream : 0.78
#
# Material property : 0.71
#
# Hair coloring : 0.51
#
# Font : 0.80
#
# Material property : 0.70
#
# Product : 0.93
#
# Red : 0.92
#
# Beauty : 0.88
#
# Lip : 0.75
#
# Material property : 0.73
#
# Hair coloring : 0.72
#
# Skin care : 0.68
#
# Face : 0.95
#
# Brush : 0.90
#
# Cosmetics : 0.89
#
# Product : 0.88
#
# Material property : 0.71
#
# Skin care : 0.67
#
# Beige : 0.67
#
# Cream : 0.64
#
# Makeup brushes : 0.64
#
# Personal care : 0.55
#
# Product : 0.95
#
# Skin care : 0.84
#
# Hair coloring : 0.81
#
# Cream : 0.76
#
# Material property : 0.72
#
# Personal care : 0.58
#
# Brand : 0.57
#
# Cosmetics : 0.56
#
# Hair care : 0.55
#
# Advertising : 0.51
#
# Hair : 0.98
#
# Face : 0.96
#
# Product : 0.93
#
# Hair coloring : 0.88
#
# Brown : 0.88
#
# Nose : 0.84
#
# Material property : 0.73
#
# Brown hair : 0.66
#
# Personal care : 0.63
#
# Hair care : 0.62
#
# Product : 0.93
#
# Personal care : 0.60
#
# Skin care : 0.59
#
# Fluid : 0.55
#
# Liquid : 0.51
#
# Product : 0.97
#
# Pink : 0.91
#
# Cosmetics : 0.82
#
# Liquid : 0.80
#
# Material property : 0.73
#
# Skin care : 0.70
#
# Tints and shades : 0.69
#
# Spray : 0.69
#
# Gloss : 0.62
#
# Perfume : 0.61
#
# Product : 0.95
#
# Font : 0.87
#
# Material property : 0.72
#
# Product : 0.93
#
# Cream : 0.74
#
# Material property : 0.72
#
# Hand : 0.66
#
# Skin care : 0.62
#
# Hair gel : 0.62
#
# Acrylic paint : 0.56
#
# Cosmetics : 0.53
#
# Paint : 0.51
#
# Product : 0.96
#
# Skin care : 0.85
#
# Water : 0.81
#
# Material property : 0.72
#
# Font : 0.69
#
# Cream : 0.66
#
# Moisture : 0.60
#
# Lip care : 0.60
#
# Cosmetics : 0.59
#
# Fluid : 0.57
#
# Product : 0.96
#
# Cheek : 0.94
#
# Pink : 0.92
#
# Skin : 0.91
#
# Lip : 0.91
#
# Beauty : 0.90
#
# Skin care : 0.82
#
# Cosmetics : 0.80
#
# Liquid : 0.75
#
# Tints and shades : 0.74
#
# Personal care : 0.55
#
# Product : 0.95
#
# Skin care : 0.74
#
# Plastic bottle : 0.72
#
# Material property : 0.70
#
# Mouth : 0.68
#
# Personal care : 0.60
#
# Cosmetics : 0.50
#
# Product : 0.95
#
# Skin care : 0.88
#
# Head : 0.88
#
# Cream : 0.76
#
# Font : 0.75
#
# Material property : 0.72
#
# Product : 0.91
#
# Hair coloring : 0.77
#
# Personal care : 0.69
#
# Bottle : 0.58
#
# Skin care : 0.58
#
# Hair care : 0.55
#
# Spray : 0.53
#
# Product : 0.91
#
# Beauty : 0.88
#
# Pink : 0.87
#
# Skin care : 0.73
#
# Material property : 0.70
#
# Lip care : 0.64
#
# Product : 0.94
#
# Pink : 0.89
#
# Lip : 0.85
#
# Skin care : 0.75
#
# Material property : 0.72
#
# Mouth : 0.68
#
# Cream : 0.67
#
# Cosmetics : 0.62

# %%
texts
# Out:
# []

# %%
f
# Out:
# 'data/L＇oreal欧莱雅 复颜洁面乳/L＇oreal欧莱雅 复颜洁面乳.jpg'

# %%
# The name of the image file to annotate
file_name = os.path.join('test.jpg')

# Loads the image into memory
with io.open(f, 'rb') as image_file:
    content = image_file.read()

image = types.Image(content=content)

# Performs label detection on the image file
response = client.label_detection(image=image)
labels = response.label_annotations


for label in labels:
    print(label.description, ': ', "{:.2f}".format(label.score) )
# Out:
# Red :  0.95
# Cosmetics :  0.94
# Lip :  0.94
# Lipstick :  0.92
# Product :  0.91
# Beauty :  0.89
# Lip gloss :  0.82
# Pink :  0.81
# Lip care :  0.76
# Material property :  0.74

# %%
response = client.text_detection(image=image)
texts = response.text_annotations
print('Texts:')

for text in texts:
    print('\n"{}"'.format(text.description))

    vertices = (['({},{})'.format(vertex.x, vertex.y)
                for vertex in text.bounding_poly.vertices])

    print('bounds: {}'.format(','.join(vertices)))
# Out:
# Texts:
#
# "#308
# L'ORÉAL
# 欧莱雅授权PARIS
# #316
# REA
# 买即赠护手霜+葫芦粉扑
# "
# bounds: (11,7),(392,7),(392,423),(11,423)
#
# "#"
# bounds: (266,8),(274,8),(275,20),(267,20)
#
# "308"
# bounds: (275,8),(301,7),(302,21),(276,22)
#
# "L'ORÉAL"
# bounds: (11,9),(115,9),(115,28),(11,28)
#
# "欧莱雅"
# bounds: (12,31),(74,31),(74,49),(12,49)
#
# "授权"
# bounds: (77,41),(95,41),(95,49),(77,49)
#
# "PARIS"
# bounds: (97,34),(123,34),(123,39),(97,39)
#
# "#"
# bounds: (266,118),(273,118),(273,130),(266,130)
#
# "316"
# bounds: (275,117),(300,117),(300,130),(275,130)
#
# "REA"
# bounds: (106,186),(119,187),(118,193),(105,192)
#
# "买"
# bounds: (36,394),(66,394),(66,423),(36,423)
#
# "即"
# bounds: (74,394),(103,394),(103,423),(74,423)
#
# "赠"
# bounds: (112,393),(141,393),(141,423),(112,423)
#
# "护手霜"
# bounds: (158,394),(248,394),(248,423),(158,423)
#
# "+"
# bounds: (251,400),(266,400),(266,417),(251,417)
#
# "葫芦"
# bounds: (270,394),(329,394),(329,422),(270,422)
#
# "粉扑"
# bounds: (331,393),(392,393),(392,423),(331,423)

# %%
texts[0]
# Out:
# locale: "zh"
# description: "LOREAL 1\346\254\247\350\216\261\351\233\205\346\216\210\346\235\203\344\270\223\345\215\226\345\272\227\nPARIS\nLOREAL\nPARIS\n22\344\271\260\345\215\263\351\200\201\345\217\221\345\270\246\nREVITALIFT\n\346\254\247\350\216\261\351\233\205\345\244\215\351\242\234\n\346\264\201\351\235\242\344\271\263\n\350\265\240\n\345\210\270\345\220\216\344\273\267:\n\302\245104\n\345\244\247\345\256\271\351\207\217125\346\257\253\345\215\207\n"
# bounding_poly {
#   vertices {
#     x: 9
#     y: 5
#   }
#   vertices {
#     x: 411
#     y: 5
#   }
#   vertices {
#     x: 411
#     y: 417
#   }
#   vertices {
#     x: 9
#     y: 417
#   }
# }

# %%
texts[0].topicality
# Out:
# 0.0

# %%
print('\n"{}"'.format(texts[0].description))
# Out:
# "L'ORÉAL
# |立减10元
# PARIS
# 巴黎欧莱雅
# 详情领券
# OREA
# EN
# 會早晚2瓶装
# 水能水凝露120ml+水能强润霜50ml |
# HYDRA
# POWER
# 上用!晚上用
# 清爽保湿深层滋养
# 券后价:-
# 早
# 109
# "

# %%
text.description
# Out:
# '109'

# %%
texts
# Out:
# [locale: "zh"
# description: "L\'OR\303\211AL\n|\347\253\213\345\207\21710\345\205\203\nPARIS\n\345\267\264\351\273\216\346\254\247\350\216\261\351\233\205\n\350\257\246\346\203\205\351\242\206\345\210\270\nOREA\nEN\n\346\234\203\346\227\251\346\231\2322\347\223\266\350\243\205\n\346\260\264\350\203\275\346\260\264\345\207\235\351\234\262120ml+\346\260\264\350\203\275\345\274\272\346\266\246\351\234\23450ml |\nHYDRA\nPOWER\n\344\270\212\347\224\250!\346\231\232\344\270\212\347\224\250\n\346\270\205\347\210\275\344\277\235\346\271\277\346\267\261\345\261\202\346\273\213\345\205\273\n\345\210\270\345\220\216\344\273\267:-\n\346\227\251\n109\n"
# bounding_poly {
#   vertices {
#     x: 6
#     y: 1
#   }
#   vertices {
#     x: 419
#     y: 1
#   }
#   vertices {
#     x: 419
#     y: 421
#   }
#   vertices {
#     x: 6
#     y: 421
#   }
# }
# , description: "L\'OR\303\211AL"
# bounding_poly {
#   vertices {
#     x: 19
#     y: 6
#   }
#   vertices {
#     x: 95
#     y: 6
#   }
#   vertices {
#     x: 95
#     y: 21
#   }
#   vertices {
#     x: 19
#     y: 21
#   }
# }
# , description: "|"
# bounding_poly {
#   vertices {
#     x: 233
#     y: 7
#   }
#   vertices {
#     x: 240
#     y: 7
#   }
#   vertices {
#     x: 242
#     y: 43
#   }
#   vertices {
#     x: 235
#     y: 43
#   }
# }
# , description: "\347\253\213"
# bounding_poly {
#   vertices {
#     x: 246
#     y: 25
#   }
#   vertices {
#     x: 275
#     y: 24
#   }
#   vertices {
#     x: 276
#     y: 48
#   }
#   vertices {
#     x: 247
#     y: 49
#   }
# }
# , description: "\345\207\217"
# bounding_poly {
#   vertices {
#     x: 279
#     y: 22
#   }
#   vertices {
#     x: 308
#     y: 21
#   }
#   vertices {
#     x: 309
#     y: 48
#   }
#   vertices {
#     x: 280
#     y: 49
#   }
# }
# , description: "10"
# bounding_poly {
#   vertices {
#     x: 310
#     y: 4
#   }
#   vertices {
#     x: 368
#     y: 1
#   }
#   vertices {
#     x: 370
#     y: 48
#   }
#   vertices {
#     x: 312
#     y: 51
#   }
# }
# , description: "\345\205\203"
# bounding_poly {
#   vertices {
#     x: 373
#     y: 23
#   }
#   vertices {
#     x: 401
#     y: 22
#   }
#   vertices {
#     x: 402
#     y: 47
#   }
#   vertices {
#     x: 374
#     y: 48
#   }
# }
# , description: "PARIS"
# bounding_poly {
#   vertices {
#     x: 46
#     y: 21
#   }
#   vertices {
#     x: 70
#     y: 22
#   }
#   vertices {
#     x: 70
#     y: 27
#   }
#   vertices {
#     x: 46
#     y: 26
#   }
# }
# , description: "\345\267\264\351\273\216"
# bounding_poly {
#   vertices {
#     x: 33
#     y: 31
#   }
#   vertices {
#     x: 51
#     y: 31
#   }
#   vertices {
#     x: 51
#     y: 39
#   }
#   vertices {
#     x: 33
#     y: 39
#   }
# }
# , description: "\346\254\247\350\216\261\351\233\205"
# bounding_poly {
#   vertices {
#     x: 53
#     y: 31
#   }
#   vertices {
#     x: 83
#     y: 31
#   }
#   vertices {
#     x: 83
#     y: 39
#   }
#   vertices {
#     x: 53
#     y: 39
#   }
# }
# , description: "\350\257\246\346\203\205"
# bounding_poly {
#   vertices {
#     x: 292
#     y: 59
#   }
#   vertices {
#     x: 321
#     y: 60
#   }
#   vertices {
#     x: 320
#     y: 74
#   }
#   vertices {
#     x: 291
#     y: 73
#   }
# }
# , description: "\351\242\206"
# bounding_poly {
#   vertices {
#     x: 324
#     y: 59
#   }
#   vertices {
#     x: 338
#     y: 60
#   }
#   vertices {
#     x: 337
#     y: 73
#   }
#   vertices {
#     x: 323
#     y: 72
#   }
# }
# , description: "\345\210\270"
# bounding_poly {
#   vertices {
#     x: 340
#     y: 59
#   }
#   vertices {
#     x: 353
#     y: 60
#   }
#   vertices {
#     x: 352
#     y: 74
#   }
#   vertices {
#     x: 339
#     y: 73
#   }
# }
# , description: "OREA"
# bounding_poly {
#   vertices {
#     x: 128
#     y: 139
#   }
#   vertices {
#     x: 162
#     y: 138
#   }
#   vertices {
#     x: 162
#     y: 147
#   }
#   vertices {
#     x: 128
#     y: 148
#   }
# }
# , description: "EN"
# bounding_poly {
#   vertices {
#     x: 127
#     y: 149
#   }
#   vertices {
#     x: 137
#     y: 149
#   }
#   vertices {
#     x: 137
#     y: 155
#   }
#   vertices {
#     x: 127
#     y: 155
#   }
# }
# , description: "\346\234\203"
# bounding_poly {
#   vertices {
#     x: 238
#     y: 127
#   }
#   vertices {
#     x: 263
#     y: 128
#   }
#   vertices {
#     x: 262
#     y: 155
#   }
#   vertices {
#     x: 237
#     y: 154
#   }
# }
# , description: "\346\227\251\346\231\232"
# bounding_poly {
#   vertices {
#     x: 270
#     y: 129
#   }
#   vertices {
#     x: 317
#     y: 131
#   }
#   vertices {
#     x: 316
#     y: 156
#   }
#   vertices {
#     x: 269
#     y: 154
#   }
# }
# , description: "2"
# bounding_poly {
#   vertices {
#     x: 319
#     y: 133
#   }
#   vertices {
#     x: 333
#     y: 134
#   }
#   vertices {
#     x: 332
#     y: 155
#   }
#   vertices {
#     x: 318
#     y: 154
#   }
# }
# , description: "\347\223\266\350\243\205"
# bounding_poly {
#   vertices {
#     x: 335
#     y: 130
#   }
#   vertices {
#     x: 383
#     y: 132
#   }
#   vertices {
#     x: 382
#     y: 156
#   }
#   vertices {
#     x: 334
#     y: 154
#   }
# }
# , description: "\346\260\264\350\203\275"
# bounding_poly {
#   vertices {
#     x: 227
#     y: 174
#   }
#   vertices {
#     x: 245
#     y: 174
#   }
#   vertices {
#     x: 245
#     y: 182
#   }
#   vertices {
#     x: 227
#     y: 182
#   }
# }
# , description: "\346\260\264"
# bounding_poly {
#   vertices {
#     x: 247
#     y: 174
#   }
#   vertices {
#     x: 255
#     y: 174
#   }
#   vertices {
#     x: 255
#     y: 182
#   }
#   vertices {
#     x: 247
#     y: 182
#   }
# }
# , description: "\345\207\235\351\234\262"
# bounding_poly {
#   vertices {
#     x: 257
#     y: 174
#   }
#   vertices {
#     x: 275
#     y: 174
#   }
#   vertices {
#     x: 275
#     y: 182
#   }
#   vertices {
#     x: 257
#     y: 182
#   }
# }
# , description: "120ml"
# bounding_poly {
#   vertices {
#     x: 278
#     y: 174
#   }
#   vertices {
#     x: 309
#     y: 174
#   }
#   vertices {
#     x: 309
#     y: 182
#   }
#   vertices {
#     x: 278
#     y: 182
#   }
# }
# , description: "+"
# bounding_poly {
#   vertices {
#     x: 310
#     y: 174
#   }
#   vertices {
#     x: 313
#     y: 174
#   }
#   vertices {
#     x: 313
#     y: 181
#   }
#   vertices {
#     x: 310
#     y: 181
#   }
# }
# , description: "\346\260\264\350\203\275"
# bounding_poly {
#   vertices {
#     x: 315
#     y: 174
#   }
#   vertices {
#     x: 334
#     y: 174
#   }
#   vertices {
#     x: 334
#     y: 182
#   }
#   vertices {
#     x: 315
#     y: 182
#   }
# }
# , description: "\345\274\272"
# bounding_poly {
#   vertices {
#     x: 336
#     y: 174
#   }
#   vertices {
#     x: 344
#     y: 174
#   }
#   vertices {
#     x: 344
#     y: 182
#   }
#   vertices {
#     x: 336
#     y: 182
#   }
# }
# , description: "\346\266\246"
# bounding_poly {
#   vertices {
#     x: 346
#     y: 174
#   }
#   vertices {
#     x: 354
#     y: 174
#   }
#   vertices {
#     x: 354
#     y: 182
#   }
#   vertices {
#     x: 346
#     y: 182
#   }
# }
# , description: "\351\234\234"
# bounding_poly {
#   vertices {
#     x: 356
#     y: 174
#   }
#   vertices {
#     x: 364
#     y: 174
#   }
#   vertices {
#     x: 364
#     y: 182
#   }
#   vertices {
#     x: 356
#     y: 182
#   }
# }
# , description: "50ml"
# bounding_poly {
#   vertices {
#     x: 366
#     y: 174
#   }
#   vertices {
#     x: 389
#     y: 174
#   }
#   vertices {
#     x: 389
#     y: 181
#   }
#   vertices {
#     x: 366
#     y: 181
#   }
# }
# , description: "|"
# bounding_poly {
#   vertices {
#     x: 394
#     y: 171
#   }
#   vertices {
#     x: 395
#     y: 171
#   }
#   vertices {
#     x: 395
#     y: 185
#   }
#   vertices {
#     x: 394
#     y: 185
#   }
# }
# , description: "HYDRA"
# bounding_poly {
#   vertices {
#     x: 322
#     y: 258
#   }
#   vertices {
#     x: 350
#     y: 258
#   }
#   vertices {
#     x: 350
#     y: 263
#   }
#   vertices {
#     x: 322
#     y: 263
#   }
# }
# , description: "POWER"
# bounding_poly {
#   vertices {
#     x: 318
#     y: 267
#   }
#   vertices {
#     x: 352
#     y: 267
#   }
#   vertices {
#     x: 352
#     y: 273
#   }
#   vertices {
#     x: 318
#     y: 273
#   }
# }
# , description: "\344\270\212"
# bounding_poly {
#   vertices {
#     x: 138
#     y: 331
#   }
#   vertices {
#     x: 165
#     y: 331
#   }
#   vertices {
#     x: 165
#     y: 357
#   }
#   vertices {
#     x: 138
#     y: 357
#   }
# }
# , description: "\347\224\250"
# bounding_poly {
#   vertices {
#     x: 169
#     y: 332
#   }
#   vertices {
#     x: 195
#     y: 332
#   }
#   vertices {
#     x: 195
#     y: 357
#   }
#   vertices {
#     x: 169
#     y: 357
#   }
# }
# , description: "!"
# bounding_poly {
#   vertices {
#     x: 225
#     y: 331
#   }
#   vertices {
#     x: 230
#     y: 331
#   }
#   vertices {
#     x: 230
#     y: 361
#   }
#   vertices {
#     x: 225
#     y: 361
#   }
# }
# , description: "\346\231\232\344\270\212"
# bounding_poly {
#   vertices {
#     x: 272
#     y: 333
#   }
#   vertices {
#     x: 329
#     y: 333
#   }
#   vertices {
#     x: 329
#     y: 360
#   }
#   vertices {
#     x: 272
#     y: 360
#   }
# }
# , description: "\347\224\250"
# bounding_poly {
#   vertices {
#     x: 332
#     y: 334
#   }
#   vertices {
#     x: 358
#     y: 334
#   }
#   vertices {
#     x: 358
#     y: 360
#   }
#   vertices {
#     x: 332
#     y: 360
#   }
# }
# , description: "\346\270\205\347\210\275"
# bounding_poly {
#   vertices {
#     x: 140
#     y: 384
#   }
#   vertices {
#     x: 204
#     y: 384
#   }
#   vertices {
#     x: 204
#     y: 415
#   }
#   vertices {
#     x: 140
#     y: 415
#   }
# }
# , description: "\344\277\235\346\271\277"
# bounding_poly {
#   vertices {
#     x: 206
#     y: 385
#   }
#   vertices {
#     x: 272
#     y: 385
#   }
#   vertices {
#     x: 272
#     y: 415
#   }
#   vertices {
#     x: 206
#     y: 415
#   }
# }
# , description: "\346\267\261\345\261\202"
# bounding_poly {
#   vertices {
#     x: 288
#     y: 385
#   }
#   vertices {
#     x: 352
#     y: 385
#   }
#   vertices {
#     x: 352
#     y: 415
#   }
#   vertices {
#     x: 288
#     y: 415
#   }
# }
# , description: "\346\273\213\345\205\273"
# bounding_poly {
#   vertices {
#     x: 355
#     y: 384
#   }
#   vertices {
#     x: 419
#     y: 384
#   }
#   vertices {
#     x: 419
#     y: 415
#   }
#   vertices {
#     x: 355
#     y: 415
#   }
# }
# , description: "\345\210\270"
# bounding_poly {
#   vertices {
#     x: 22
#     y: 344
#   }
#   vertices {
#     x: 42
#     y: 344
#   }
#   vertices {
#     x: 42
#     y: 365
#   }
#   vertices {
#     x: 22
#     y: 365
#   }
# }
# , description: "\345\220\216"
# bounding_poly {
#   vertices {
#     x: 44
#     y: 344
#   }
#   vertices {
#     x: 66
#     y: 344
#   }
#   vertices {
#     x: 66
#     y: 364
#   }
#   vertices {
#     x: 44
#     y: 364
#   }
# }
# , description: "\344\273\267"
# bounding_poly {
#   vertices {
#     x: 68
#     y: 344
#   }
#   vertices {
#     x: 89
#     y: 344
#   }
#   vertices {
#     x: 89
#     y: 365
#   }
#   vertices {
#     x: 68
#     y: 365
#   }
# }
# , description: ":"
# bounding_poly {
#   vertices {
#     x: 94
#     y: 348
#   }
#   vertices {
#     x: 99
#     y: 348
#   }
#   vertices {
#     x: 99
#     y: 363
#   }
#   vertices {
#     x: 94
#     y: 363
#   }
# }
# , description: "-"
# bounding_poly {
#   vertices {
#     x: 114
#     y: 347
#   }
#   vertices {
#     x: 118
#     y: 347
#   }
#   vertices {
#     x: 118
#     y: 348
#   }
#   vertices {
#     x: 114
#     y: 348
#   }
# }
# , description: "\346\227\251"
# bounding_poly {
#   vertices {
#     x: 104
#     y: 333
#   }
#   vertices {
#     x: 133
#     y: 331
#   }
#   vertices {
#     x: 135
#     y: 356
#   }
#   vertices {
#     x: 106
#     y: 358
#   }
# }
# , description: "109"
# bounding_poly {
#   vertices {
#     x: 7
#     y: 370
#   }
#   vertices {
#     x: 134
#     y: 372
#   }
#   vertices {
#     x: 133
#     y: 421
#   }
#   vertices {
#     x: 6
#     y: 419
#   }
# }
# ]
