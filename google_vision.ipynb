# %%
# %env GOOGLE_APPLICATION_CREDENTIALS=/Users/roger/Drive_Artefact/TMALL/Code/Data Sandbox-3580c14f7592.json
# Out:
# env: GOOGLE_APPLICATION_CREDENTIALS=/Users/roger/Drive_Artefact/TMALL/Code/Data Sandbox-3580c14f7592.json

# %%
import re
import pprint
import io
import os
# Imports the Google Cloud client library
from google.cloud import vision
from google.cloud.vision import types

# Instantiates a client
client = vision.ImageAnnotatorClient()

path = 'data/'

files = []
# r=root, d=directories, f = files
for r, d, f in os.walk(path):
    for file in f:
        if '.jpg' in file:
            files.append(os.path.join(r, file))
path = []
for f in files:
    path.append(f.split('/')[0]+ '/' + f.split('/')[1] + '/')

file_names= []
for f in files:
    file_names.append(f.split('/')[2].split('.')[0])

# %%
path
# Out:
# ["data/L'OREAL 欧莱雅 恒放溢彩雾感唇釉/",
#  "data/L'OREAL 欧莱雅 清润红石榴鲜粹面膜/",
#  'data/error_20190320_191821/',
#  'data/L＇oreal欧莱雅 茶树植萃去屑滋养洗发露/',
#  'data/error_20190320_192255/',
#  'data/error_20190320_191827/',
#  "data/L'OREAL 欧莱雅 清润葡萄籽鲜粹精华液/",
#  'data/L＇oreal欧莱雅 奇焕光感粉嫩透亮修颜霜/',
#  'data/error_20190320_191811/',
#  "data/L'OREAL 欧莱雅 强塑定型三孔喷雾/",
#  "data/L'OREAL 欧莱雅 奇焕润发精油(针对极度干枯发质)/",
#  'data/L＇oreal欧莱雅 男士火山岩清痘冰感水凝露/',
#  'data/error_20190320_192147/',
#  'data/error_20190320_191738/',
#  "data/L'OREAL 欧莱雅 青春密码酵素精华肌底液/",
#  "data/L'OREAL 欧莱雅 清润葡萄籽精华膜力水/",
#  "data/L'OREAL 欧莱雅 男士锐能抗皱紧致多效霜/",
#  'data/error_20190320_192115/',
#  'data/L＇oreal欧莱雅 男士水能保湿滋润乳/',
#  "data/L'OREAL 欧莱雅 精油润养润发乳/",
#  "data/L'OREAL 欧莱雅 纷泽溢彩釉光唇膏/",
#  "data/L'OREAL欧莱雅 透明质酸水润去屑洗发露(倍爽)/",
#  'data/error_20190320_192141/',
#  'data/L＇oreal欧莱雅 男士水能润泽双效洁面膏/',
#  'data/L＇oreal欧莱雅 男士水能保湿强润霜/',
#  'data/error_20190320_192249/',
#  "data/L'OREAL 欧莱雅 恒放溢彩持色哑光遮瑕轻垫霜/",
#  'data/error_20190320_192026/',
#  'data/L＇oreal欧莱雅 男士水能润泽净爽洁面啫喱/',
#  "data/L'OREAL 欧莱雅 精油润养洗发露/",
#  'data/error_20190320_191651/',
#  'data/error_20190320_192016/',
#  'data/error_20190320_191624/',
#  'data/L＇oreal欧莱雅 三合一卸妆洁颜水 深澈型/',
#  'data/error_20190320_192202/',
#  'data/error_20190320_192054/',
#  "data/L'OREAL 欧莱雅 奇焕润发精油 适合各种发质/",
#  'data/error_20190320_191622/',
#  "data/L'OREAL欧莱雅 男士去屑洗发露(炭爽去油)/",
#  'data/error_20190320_192009/',
#  "data/L'OREAL 欧莱雅 男士火山岩控油清痘洁面膏/",
#  'data/L＇oreal欧莱雅 男士水能保湿酷爽水凝露/',
#  "data/L'OREAL 欧莱雅 复颜抗皱紧致滋润日霜/",
#  "data/L'OREAL 欧莱雅 复颜玻尿酸水光充盈全脸淡纹眼霜/",
#  'data/巴黎欧莱雅 复颜紧致三件套超值组合/',
#  "data/L'OREAL 欧莱雅 恒放溢彩持色哑光粉底液/",
#  'data/L＇oreal欧莱雅 男士控油炭爽抗黑头洁面膏/',
#  "data/L'OREAL 欧莱雅 轻爽塑型啫喱/",
#  "data/L'OREAL 欧莱雅 三合一卸妆洁颜水清爽型/",
#  'data/error_20190320_191744/',
#  'data/error_20190320_192132/',
#  'data/error_20190320_192104/',
#  'data/L＇oreal欧莱雅 多重防护隔离露(特护升级)SPF30+PA+++/',
#  'data/error_20190320_191710/',
#  "data/L'OREAL 欧莱雅 茶树植萃去屑净油洗发露/",
#  'data/L＇oreal欧莱雅 透明质酸水润洗发露/',
#  "data/L'OREAL 欧莱雅 清润葡萄籽水嫩洁面乳/",
#  "data/L'OREAL 欧莱雅 奇焕润发精油/",
#  'data/L＇oreal欧莱雅 清润葡萄籽水嫩膜力眼霜/',
#  'data/L＇oreal欧莱雅 复颜洁面乳/']

# %%
for counter, f in enumerate(files):
    
    # Loads the image into memory
    with io.open(f, 'rb') as image_file:
        content = image_file.read()

    image = types.Image(content=content)

    # Performs label detection on the image file
    response = client.text_detection(image=image)
    texts = response.text_annotations
    
    doc_txt = open(path[counter] + "text.txt","w")
    doc_txt.write(texts[0].description)
    doc_txt.close()
    
    doc_desc = open(path[counter] + "desc.txt","w")

    for text in texts[1:]:
        vertices = (['({},{})'.format(vertex.x, vertex.y)
                    for vertex in text.bounding_poly.vertices])
        doc_desc.write('\n"{}"'.format(text.description))
        doc_desc.write('bounds: {}'.format(','.join(vertices)))
    doc_desc.close()
    
    response = client.label_detection(image=image)
    labels = response.label_annotations
    doc_label = open(path[counter] + "label.txt","w")
    for label in labels:
        doc_label.write(label.description + ': '+ "{:.2f}".format(label.score) + '\n')
    doc_label.close()
# Out:
# Red : 0.95
#
# Cosmetics : 0.94
#
# Lip : 0.94
#
# Lipstick : 0.92
#
# Product : 0.91
#
# Beauty : 0.89
#
# Lip gloss : 0.82
#
# Pink : 0.81
#
# Lip care : 0.76
#
# Material property : 0.74
#
# Pink : 0.88
#
# Font : 0.78
#
# Material property : 0.70
#
# Magenta : 0.70
#
# Advertising : 0.53
#
# Product : 0.95
#
# Material property : 0.72
#
# Personal care : 0.60
#
# Electric blue : 0.58
#
# Skin care : 0.56
#
# Hair care : 0.55
#
# Hair coloring : 0.51
#
# Product : 0.88
#
# Liquid : 0.57
#
# Product : 0.97
#
# Pink : 0.92
#
# Skin care : 0.81
#
# Liquid : 0.74
#
# Cosmetics : 0.73
#
# Material property : 0.72
#
# Fluid : 0.60
#
# Tints and shades : 0.56
#
# Gloss : 0.55
#
# Moisture : 0.55
#
# Product : 0.96
#
# Water : 0.81
#
# Spray : 0.79
#
# Bottle : 0.76
#
# Liquid : 0.71
#
# Material property : 0.70
#
# Plastic bottle : 0.65
#
# Cosmetics : 0.60
#
# Fluid : 0.53
#
# Personal care : 0.53
#
# Product : 0.96
#
# Pink : 0.90
#
# Beauty : 0.89
#
# Water : 0.81
#
# Skin care : 0.78
#
# Cosmetics : 0.75
#
# Material property : 0.72
#
# Liquid : 0.65
#
# Fluid : 0.63
#
# Lip care : 0.59
#
# Skin care : 0.90
#
# Product : 0.88
#
# Cosmetics : 0.83
#
# Lip care : 0.78
#
# Cream : 0.77
#
# Font : 0.75
#
# Material property : 0.73
#
# Brand : 0.58
#
# Product : 0.95
#
# Plastic bottle : 0.81
#
# Skin care : 0.74
#
# Spray : 0.72
#
# Material property : 0.71
#
# Bottle : 0.71
#
# Fluid : 0.69
#
# Cosmetics : 0.69
#
# Liquid : 0.67
#
# Tints and shades : 0.52
#
# Product : 0.93
#
# Material property : 0.70
#
# Product : 0.88
#
# Bottle : 0.66
#
# Spray : 0.63
#
# Fluid : 0.51
#
# Product : 0.96
#
# Beauty : 0.88
#
# Personal care : 0.71
#
# Material property : 0.70
#
# Skin care : 0.61
#
# Hair coloring : 0.55
#
# Hair care : 0.52
#
# Lipstick : 0.97
#
# Red : 0.96
#
# Lip : 0.94
#
# Cosmetics : 0.94
#
# Lip care : 0.91
#
# Pink : 0.81
#
# Material property : 0.72
#
# Mouth : 0.68
#
# Tints and shades : 0.60
#
# Lip gloss : 0.55
#
# Product : 0.88
#
# Skin care : 0.55
#
# Product : 0.97
#
# Beauty : 0.86
#
# Water : 0.81
#
# Font : 0.75
#
# Material property : 0.72
#
# Skin care : 0.66
#
# Personal care : 0.58
#
# Hair care : 0.58
#
# Spray : 0.53
#
# Moisture : 0.52
#
# Product : 0.95
#
# Pink : 0.81
#
# Perfume : 0.71
#
# Material property : 0.70
#
# Liquid : 0.64
#
# Fluid : 0.61
#
# Product : 0.95
#
# Hair coloring : 0.83
#
# Skin care : 0.79
#
# Material property : 0.72
#
# Cream : 0.71
#
# Personal care : 0.61
#
# Hair care : 0.55
#
# Product : 0.96
#
# Beauty : 0.87
#
# Skin care : 0.86
#
# Cream : 0.76
#
# Hair coloring : 0.76
#
# Material property : 0.72
#
# Lotion : 0.63
#
# Advertising : 0.61
#
# Hair care : 0.58
#
# Brand : 0.57
#
# Product : 0.93
#
# Material property : 0.71
#
# Product : 0.91
#
# Material property : 0.70
#
# Lip : 0.97
#
# Lipstick : 0.97
#
# Red : 0.95
#
# Cosmetics : 0.93
#
# Pink : 0.93
#
# Lip care : 0.92
#
# Lip gloss : 0.91
#
# Beauty : 0.87
#
# Tints and shades : 0.75
#
# Material property : 0.74
#
# Product : 0.91
#
# Personal care : 0.61
#
# Fluid : 0.53
#
# Material property : 0.72
#
# Hair coloring : 0.60
#
# Cosmetics : 0.52
#
# Liquid : 0.51
#
# Product : 0.88
#
# Skin care : 0.78
#
# Material property : 0.71
#
# Font : 0.69
#
# Hair coloring : 0.64
#
# Personal care : 0.54
#
# Product : 0.91
#
# Font : 0.75
#
# Material property : 0.70
#
# Personal care : 0.53
#
# Hair care : 0.52
#
# Product : 0.91
#
# Material property : 0.72
#
# Skin care : 0.69
#
# Cosmetics : 0.67
#
# Hair coloring : 0.62
#
# Cream : 0.62
#
# Font : 0.82
#
# Fashion accessory : 0.55
#
# Product : 0.96
#
# Cosmetics : 0.88
#
# Liquid : 0.75
#
# Material property : 0.73
#
# Gloss : 0.61
#
# Hair coloring : 0.60
#
# Eyelash : 0.59
#
# Product : 0.95
#
# Skin care : 0.85
#
# Cream : 0.75
#
# Material property : 0.71
#
# Font : 0.69
#
# Brand : 0.60
#
# Acrylic paint : 0.57
#
# Product : 0.91
#
# Material property : 0.71
#
# Personal care : 0.62
#
# Skin care : 0.61
#
# Hair coloring : 0.58
#
# Spray : 0.56
#
# Hair care : 0.50
#
# Product : 0.94
#
# Font : 0.85
#
# Material property : 0.72
#
# Hair coloring : 0.51
#
# Product : 0.96
#
# Water : 0.81
#
# Spray : 0.79
#
# Bottle : 0.76
#
# Liquid : 0.71
#
# Material property : 0.70
#
# Plastic bottle : 0.65
#
# Cosmetics : 0.60
#
# Fluid : 0.53
#
# Personal care : 0.53
#
# Product : 0.97
#
# Pink : 0.92
#
# Skin care : 0.81
#
# Liquid : 0.74
#
# Cosmetics : 0.73
#
# Material property : 0.72
#
# Fluid : 0.60
#
# Tints and shades : 0.56
#
# Gloss : 0.55
#
# Moisture : 0.55
#
# Product : 0.96
#
# Skin care : 0.78
#
# Material property : 0.70
#
# Product : 0.88
#
# Material property : 0.72
#
# Cream : 0.69
#
# Font : 0.69
#
# Skin care : 0.68
#
# Hair coloring : 0.60
#
# Brand : 0.52
#
# Product : 0.95
#
# Red : 0.94
#
# Skin : 0.92
#
# Beauty : 0.90
#
# Skin care : 0.86
#
# Hair coloring : 0.83
#
# Lip : 0.83
#
# Material property : 0.72
#
# Cosmetics : 0.63
#
# Gloss : 0.51
#
# Product : 0.91
#
# Hair coloring : 0.77
#
# Personal care : 0.69
#
# Bottle : 0.58
#
# Skin care : 0.58
#
# Hair care : 0.55
#
# Spray : 0.53
#
# Product : 0.91
#
# Material property : 0.72
#
# Skin care : 0.69
#
# Cosmetics : 0.67
#
# Hair coloring : 0.62
#
# Cream : 0.62
#
# Product : 0.93
#
# Material property : 0.70
#
# Liquid : 0.62
#
# Personal care : 0.53
#
# Hair coloring : 0.51
#
# Product : 0.95
#
# Material property : 0.72
#
# Personal care : 0.60
#
# Electric blue : 0.58
#
# Skin care : 0.56
#
# Hair care : 0.55
#
# Hair coloring : 0.51
#
# Product : 0.95
#
# Hair coloring : 0.79
#
# Skin care : 0.77
#
# Cream : 0.72
#
# Material property : 0.71
#
# Brand : 0.60
#
# Advertising : 0.58
#
# Personal care : 0.54
#
# Product : 0.95
#
# Material property : 0.72
#
# Personal care : 0.68
#
# Hair coloring : 0.62
#
# Hair care : 0.60
#
# Skin care : 0.60
#
# Cosmetics : 0.58
#
# Product : 0.95
#
# Red : 0.95
#
# Skin care : 0.91
#
# Beauty : 0.86
#
# Cream : 0.78
#
# Material property : 0.71
#
# Hair coloring : 0.51
#
# Font : 0.80
#
# Material property : 0.70
#
# Product : 0.93
#
# Red : 0.92
#
# Beauty : 0.88
#
# Lip : 0.75
#
# Material property : 0.73
#
# Hair coloring : 0.72
#
# Skin care : 0.68
#
# Face : 0.95
#
# Brush : 0.90
#
# Cosmetics : 0.89
#
# Product : 0.88
#
# Material property : 0.71
#
# Skin care : 0.67
#
# Beige : 0.67
#
# Cream : 0.64
#
# Makeup brushes : 0.64
#
# Personal care : 0.55
#
# Product : 0.95
#
# Skin care : 0.84
#
# Hair coloring : 0.81
#
# Cream : 0.76
#
# Material property : 0.72
#
# Personal care : 0.58
#
# Brand : 0.57
#
# Cosmetics : 0.56
#
# Hair care : 0.55
#
# Advertising : 0.51
#
# Hair : 0.98
#
# Face : 0.96
#
# Product : 0.93
#
# Hair coloring : 0.88
#
# Brown : 0.88
#
# Nose : 0.84
#
# Material property : 0.73
#
# Brown hair : 0.66
#
# Personal care : 0.63
#
# Hair care : 0.62
#
# Product : 0.93
#
# Personal care : 0.60
#
# Skin care : 0.59
#
# Fluid : 0.55
#
# Liquid : 0.51
#
# Product : 0.97
#
# Pink : 0.91
#
# Cosmetics : 0.82
#
# Liquid : 0.80
#
# Material property : 0.73
#
# Skin care : 0.70
#
# Tints and shades : 0.69
#
# Spray : 0.69
#
# Gloss : 0.62
#
# Perfume : 0.61
#
# Product : 0.95
#
# Font : 0.87
#
# Material property : 0.72
#
# Product : 0.93
#
# Cream : 0.74
#
# Material property : 0.72
#
# Hand : 0.66
#
# Skin care : 0.62
#
# Hair gel : 0.62
#
# Acrylic paint : 0.56
#
# Cosmetics : 0.53
#
# Paint : 0.51
#
# Product : 0.96
#
# Skin care : 0.85
#
# Water : 0.81
#
# Material property : 0.72
#
# Font : 0.69
#
# Cream : 0.66
#
# Moisture : 0.60
#
# Lip care : 0.60
#
# Cosmetics : 0.59
#
# Fluid : 0.57
#
# Product : 0.96
#
# Cheek : 0.94
#
# Pink : 0.92
#
# Skin : 0.91
#
# Lip : 0.91
#
# Beauty : 0.90
#
# Skin care : 0.82
#
# Cosmetics : 0.80
#
# Liquid : 0.75
#
# Tints and shades : 0.74
#
# Personal care : 0.55
#
# Product : 0.95
#
# Skin care : 0.74
#
# Plastic bottle : 0.72
#
# Material property : 0.70
#
# Mouth : 0.68
#
# Personal care : 0.60
#
# Cosmetics : 0.50
#
# Product : 0.95
#
# Skin care : 0.88
#
# Head : 0.88
#
# Cream : 0.76
#
# Font : 0.75
#
# Material property : 0.72
#
# Product : 0.91
#
# Hair coloring : 0.77
#
# Personal care : 0.69
#
# Bottle : 0.58
#
# Skin care : 0.58
#
# Hair care : 0.55
#
# Spray : 0.53
#
# Product : 0.91
#
# Beauty : 0.88
#
# Pink : 0.87
#
# Skin care : 0.73
#
# Material property : 0.70
#
# Lip care : 0.64
#
# Product : 0.94
#
# Pink : 0.89
#
# Lip : 0.85
#
# Skin care : 0.75
#
# Material property : 0.72
#
# Mouth : 0.68
#
# Cream : 0.67
#
# Cosmetics : 0.62

# %%
response = client.text_detection(image=image)
texts = response.text_annotations
print('Texts:')

for text in texts:
    print('\n"{}"'.format(text.description))

    vertices = (['({},{})'.format(vertex.x, vertex.y)
                for vertex in text.bounding_poly.vertices])

    print('bounds: {}'.format(','.join(vertices)))
# Out:
# Texts:
#
# "#308
# L'ORÉAL
# 欧莱雅授权PARIS
# #316
# REA
# 买即赠护手霜+葫芦粉扑
# "
# bounds: (11,7),(392,7),(392,423),(11,423)
#
# "#"
# bounds: (266,8),(274,8),(275,20),(267,20)
#
# "308"
# bounds: (275,8),(301,7),(302,21),(276,22)
#
# "L'ORÉAL"
# bounds: (11,9),(115,9),(115,28),(11,28)
#
# "欧莱雅"
# bounds: (12,31),(74,31),(74,49),(12,49)
#
# "授权"
# bounds: (77,41),(95,41),(95,49),(77,49)
#
# "PARIS"
# bounds: (97,34),(123,34),(123,39),(97,39)
#
# "#"
# bounds: (266,118),(273,118),(273,130),(266,130)
#
# "316"
# bounds: (275,117),(300,117),(300,130),(275,130)
#
# "REA"
# bounds: (106,186),(119,187),(118,193),(105,192)
#
# "买"
# bounds: (36,394),(66,394),(66,423),(36,423)
#
# "即"
# bounds: (74,394),(103,394),(103,423),(74,423)
#
# "赠"
# bounds: (112,393),(141,393),(141,423),(112,423)
#
# "护手霜"
# bounds: (158,394),(248,394),(248,423),(158,423)
#
# "+"
# bounds: (251,400),(266,400),(266,417),(251,417)
#
# "葫芦"
# bounds: (270,394),(329,394),(329,422),(270,422)
#
# "粉扑"
# bounds: (331,393),(392,393),(392,423),(331,423)
